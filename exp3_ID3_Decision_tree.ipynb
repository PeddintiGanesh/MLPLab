# %%
#from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
iris = load_iris()
x = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=0)

# %%
st_x = StandardScaler()
st_x.fit(X_train)
X_train = st_x.transform(X_train)
X_test = st_x.transform(X_test)

# %%
clf_entropy = tree.DecisionTreeClassifier(criterion = "entropy", random_state =100, max_depth = 3)
clf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=100)

# %%
y_pred = clf_entropy.predict(X_test)
print("Predicted values : ", y_pred)
# Out:
# Predicted values :  [2 1 0 2 0 2 0 1 1 1 2 1 1 1 1 0 1 1 0 0 2 1 0 0 1 0 0 1 1 0]

# %%
y_pred = [iris.target_names[i] for i in y_pred]
print("Predicted values : ", y_pred)
# Out:
# Predicted values :  ['virginica', 'versicolor', 'setosa', 'virginica', 'setosa', 'virginica', 'setosa', 'versicolor', 'versicolor', 'versicolor', 'virginica', 'versicolor', 'versicolor', 'versicolor', 'versicolor', 'setosa', 'versicolor', 'versicolor', 'setosa', 'setosa', 'virginica', 'versicolor', 'setosa', 'setosa', 'versicolor', 'setosa', 'setosa', 'versicolor', 'versicolor', 'setosa']

# %%
print("Accuracy : ", end="")
print(clf_entropy.score(X_test, y_test))
# Out:
# Accuracy : 0.9666666666666667

# %%
plt.figure(figsize=(12,8))
tree.plot_tree(clf_entropy, filled = True)
plt.title("Decision Tree using entropy")
plt.show()

# %%
text_representation = tree.export_text(clf_entropy)
print("Decision Tree Representation: ")
print(text_representation)
# Out:
# Decision Tree Representation:
# |--- feature_2 <= -0.82
# |   |--- class: 0
# |--- feature_2 >  -0.82
# |   |--- feature_3 <= 0.67
# |   |   |--- feature_2 <= 0.64
# |   |   |   |--- class: 1
# |   |   |--- feature_2 >  0.64
# |   |   |   |--- class: 2
# |   |--- feature_3 >  0.67
# |   |   |--- feature_2 <= 0.58
# |   |   |   |--- class: 1
# |   |   |--- feature_2 >  0.58
# |   |   |   |--- class: 2
